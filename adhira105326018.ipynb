# %%
#Toko Dorayaki Doraemon

# 1. input nama makanan,nama karakter,dan kata sifat
nama_makanan = input("masukkan nama makanan: ") #contoh: dorayaki
nama_karakter = input("masukkan nama karakter: ") #contoh: doraemon
kata_sifat = input("masukkan kata sifat: ") #contoh: gacor

# 2. gabungkan menjadi nama toko
nama_toko = nama_makanan + " " + nama_karakter + " " + kata_sifat
print("Nama resmi toko adalah", nama_toko)

# 3. modal awal masing-masing
doraemon = 555000
nobita = 333000
shizuka = 222000

# 4. hitung total modal
total_modal = doraemon + nobita + shizuka
print("total modal awal:", total_modal)

# 5. data penjualan bulan pertama
jumlah_dorayaki = 350  #jumlah dorayaki terjual
harga_dorayaki = 5000  #harga per buah

# hitung pendapatan
total_pendapatan = jumlah_dorayaki * harga_dorayaki
print("Total pendapatan:", total_pendapatan)

# 6. hitung keuntungan bulan pertama
keuntungan = total_pendapatan - total_modal
print("Keuntungan total adalah:", keuntungan)  #perbaikan kode error Nobita

# 7. penjelasan error Nobita:
# Nobita menulis: print("Keuntungan total adalah" keuntungan)
# Error karena tanda koma (,) atau tanda + hilang antara string dan variabel.
# Seharusnya: print("Keuntungan total adalah", keuntungan) atau print("Keuntungan total adalah " + str(keuntungan))
# Out:
# Nama resmi toko adalah mie ayam sukuna baik
# total modal awal: 1110000
# Total pendapatan: 1750000
# Keuntungan total adalah: 640000
